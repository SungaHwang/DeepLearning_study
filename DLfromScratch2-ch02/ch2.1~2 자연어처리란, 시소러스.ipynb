# %% [markdown]
# 밑바닥부터 시작하는 딥러닝 2
# # 2.1 자연어 처리란

# %% [markdown]
# -> 우리의 말을 컴퓨터에게 이해시키기 위한 기술

# %%
# 단어의 의미 이해시키기

# %% [markdown]
# # 2.2 시소러스

# %% [markdown]
# ![fig%202-1.png](attachment:fig%202-1.png)

# %% [markdown]
# ![fig%202-2.png](attachment:fig%202-2.png)

# %% [markdown]
# 가장 유명한 시소러스: WordNet

# %% [markdown]
# * 유의어, 단어 네트워크 이용-> 단어 사이의 유사도 구할 수 있음
# * 문제점: 시대 변화에 대응하기 어렵고 단어의 미묘한 차이는 표현하기 어려운 큰 문제점이 있어 잘 사용하지 않음
